# %% [markdown]
# # Figure 3
#
# This plot comparse the Matrix-based segmented scan versus the vector based scan

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from glob import glob
from os.path import join

pd.set_option('display.max_rows', 1000)

tot_dataframe = pd.concat(map(pd.read_csv, glob(join('..', f"bench_results*seg_scan_sc*fp16*.csv"))))

# %%
tot_dataframe.head(10)
# Out:
#          benchname             operator dtype     time_us
# 0          pdb1HYS      seg_scan_sc_128  fp16     5295.63
# 0  mac_econ_fwd500      seg_scan_sc_128  fp16     1512.18
# 0        ASIC_680k  vec_seg_scan_sc_128  fp16   142914.12
# 0          pdb1HYS  vec_seg_scan_sc_128  fp16   158564.52
# 0          mc2depi  vec_seg_scan_sc_128  fp16    78291.95
# 0        circuit5M  vec_seg_scan_sc_128  fp16  2097665.15
# 0  mac_econ_fwd500  vec_seg_scan_sc_128  fp16    48708.75
# 0        ASIC_680k      seg_scan_sc_128  fp16     4745.39
# 0        circuit5M      seg_scan_sc_128  fp16    32962.03
# 0          mc2depi      seg_scan_sc_128  fp16     1306.69

# %%
plt.figure(figsize=(10,6))
ax = sns.barplot(data=tot_dataframe, x="benchname", y="time_us", hue="operator", edgecolor="black")
plt.yscale("log")   

plt.savefig("sparsesuite_comparison_latency.pdf")
