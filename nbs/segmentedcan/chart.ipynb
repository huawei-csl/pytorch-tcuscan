# %%
# !pip install pandas

# %%
# !pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import os

pd.set_option('display.max_rows', 1000)


current_path = os.getcwd()
directory = os.path.join(current_path)
tot_dataframe = pd.DataFrame()
for root,dirs,files in os.walk(directory):
    for file in files:
       if file.endswith(".csv"):
          data = pd.read_csv(file)
          df = pd.DataFrame(data)
          tot_dataframe = pd.concat([tot_dataframe,df])

input_size = tot_dataframe['size'] * 2 + tot_dataframe['size'] 
output_size = tot_dataframe['size'] * 4
tot_dataframe['mem_bytes'] = (tot_dataframe['size'] * (2 + 1))  + tot_dataframe['size'] * 4
#print(
tot_dataframe['bandwidth_mbps'] = (tot_dataframe['mem_bytes']) / (tot_dataframe['time_us']) #MB/s
tot_dataframe["density"] = ["$%s$" % x for x in tot_dataframe["density"]]
# Out:
#        operator dtype   size    s  density   time_us  mem_bytes
# 0   seg_scan_sc  fp16   1024   32    0.700    336.47       7168
# 1   seg_scan_sc  fp16   2048   32    0.700    590.44      14336
# 2   seg_scan_sc  fp16   3072   32    0.700    837.62      21504
# 3   seg_scan_sc  fp16   4096   32    0.700   1067.37      28672
# 4   seg_scan_sc  fp16   5120   32    0.700   1327.12      35840
# 5   seg_scan_sc  fp16   6144   32    0.700   1556.53      43008
# 6   seg_scan_sc  fp16   7168   32    0.700   1831.65      50176
# 7   seg_scan_sc  fp16   8192   32    0.700   2077.56      57344
# 8   seg_scan_sc  fp16   9216   32    0.700   2304.77      64512
# 9   seg_scan_sc  fp16  10240   32    0.700   2604.62      71680
# 10  seg_scan_sc  fp16  11264   32    0.700   2831.34      78848
# 11  seg_scan_sc  fp16  12288   32    0.700   3058.83      86016
# 12  seg_scan_sc  fp16  13312   32    0.700   3294.11      93184
# 13  seg_scan_sc  fp16  14336   32    0.700   3578.20     100352
# 14  seg_scan_sc  fp16  15360   32    0.700   3856.75     107520
# 15  seg_scan_sc  fp16  16384   32    0.700   4058.52     114688
# 16  seg_scan_sc  fp16  24576   32    0.700   6058.44     172032
# 17  seg_scan_sc  fp16  32768   32    0.700   8030.15     229376
# 18  seg_scan_sc  fp16  45056   32    0.700  11002.44     315392
# 19  seg_scan_sc  fp16   4096   64    0.700   1092.33      28672
# 20  seg_scan_sc  fp16   8192   64    0.700   2046.70      57344
# 21  seg_scan_sc  fp16  12288   64    0.700   3044.60      86016
# 22  seg_scan_sc  fp16  16384   64    0.700   4063.52     114688
# 23  seg_scan_sc  fp16  20480   64    0.700   5012.17     143360
# 24  seg_scan_sc  fp16  24576   64    0.700   5976.52     172032
# 25  seg_scan_sc  fp16  28672   64    0.700   6959.67     200704
# 26  seg_scan_sc  fp16  32768   64    0.700   7934.87     229376
# 27  seg_scan_sc  fp16  36864   64    0.700   8933.37     258048
# 28  seg_scan_sc  fp16  40960   64    0.700   9934.53     286720
# 29  seg_scan_sc  fp16  45056   64    0.700  10857.38     315392
# 30  seg_scan_sc  fp16  49152   64    0.700  11875.13     344064
# 31  seg_scan_sc  fp16  16384  128    0.700   4105.50     114688
# 32  seg_scan_sc  fp16  32768  128    0.700   8065.03     229376
# 33  seg_scan_sc  fp16  49152  128    0.700  11981.46     344064
# 0   seg_scan_sc  fp16   1024   32    0.300    201.15       7168
# 1   seg_scan_sc  fp16   2048   32    0.300    319.78      14336
# 2   seg_scan_sc  fp16   3072   32    0.300    425.96      21504
# 3   seg_scan_sc  fp16   4096   32    0.300    552.39      28672
# 4   seg_scan_sc  fp16   5120   32    0.300    650.53      35840
# 5   seg_scan_sc  fp16   6144   32    0.300    757.29      43008
# 6   seg_scan_sc  fp16   7168   32    0.300    887.87      50176
# 7   seg_scan_sc  fp16   8192   32    0.300   1003.83      57344
# 8   seg_scan_sc  fp16   9216   32    0.300   1087.67      64512
# 9   seg_scan_sc  fp16  10240   32    0.300   1225.87      71680
# 10  seg_scan_sc  fp16  11264   32    0.300   1335.86      78848
# 11  seg_scan_sc  fp16  12288   32    0.300   1397.86      86016
# 12  seg_scan_sc  fp16  13312   32    0.300   1563.89      93184
# 13  seg_scan_sc  fp16  14336   32    0.300   1682.78     100352
# 14  seg_scan_sc  fp16  15360   32    0.300   1724.82     107520
# 15  seg_scan_sc  fp16  16384   32    0.300   1905.74     114688
# 16  seg_scan_sc  fp16  24576   32    0.300   2806.53     172032
# 17  seg_scan_sc  fp16  32768   32    0.300   3694.67     229376
# 18  seg_scan_sc  fp16  45056   32    0.300   5069.25     315392
# 19  seg_scan_sc  fp16   4096   64    0.300    531.02      28672
# 20  seg_scan_sc  fp16   8192   64    0.300    962.22      57344
# 21  seg_scan_sc  fp16  12288   64    0.300   1404.99      86016
# 22  seg_scan_sc  fp16  16384   64    0.300   1852.38     114688
# 23  seg_scan_sc  fp16  20480   64    0.300   2191.58     143360
# 24  seg_scan_sc  fp16  24576   64    0.300   2688.54     172032
# 25  seg_scan_sc  fp16  28672   64    0.300   3157.10     200704
# 26  seg_scan_sc  fp16  32768   64    0.300   3550.38     229376
# 27  seg_scan_sc  fp16  36864   64    0.300   3980.79     258048
# 28  seg_scan_sc  fp16  40960   64    0.300   4385.02     286720
# 29  seg_scan_sc  fp16  45056   64    0.300   4829.21     315392
# 30  seg_scan_sc  fp16  49152   64    0.300   5323.92     344064
# 31  seg_scan_sc  fp16  16384  128    0.300   1836.60     114688
# 32  seg_scan_sc  fp16  32768  128    0.300   3608.49     229376
# 33  seg_scan_sc  fp16  49152  128    0.300   5339.57     344064
# 0   seg_scan_sc  fp16   1024   32    0.100    132.55       7168
# 1   seg_scan_sc  fp16   2048   32    0.100    186.16      14336
# 2   seg_scan_sc  fp16   3072   32    0.100    217.35      21504
# 3   seg_scan_sc  fp16   4096   32    0.100    272.31      28672
# 4   seg_scan_sc  fp16   5120   32    0.100    295.45      35840
# 5   seg_scan_sc  fp16   6144   32    0.100    363.20      43008
# 6   seg_scan_sc  fp16   7168   32    0.100    400.79      50176
# 7   seg_scan_sc  fp16   8192   32    0.100    445.45      57344
# 8   seg_scan_sc  fp16   9216   32    0.100    481.84      64512
# 9   seg_scan_sc  fp16  10240   32    0.100    530.02      71680
# 10  seg_scan_sc  fp16  11264   32    0.100    570.57      78848
# 11  seg_scan_sc  fp16  12288   32    0.100    628.15      86016
# 12  seg_scan_sc  fp16  13312   32    0.100    654.60      93184
# 13  seg_scan_sc  fp16  14336   32    0.100    706.55     100352
# 14  seg_scan_sc  fp16  15360   32    0.100    756.08     107520
# 15  seg_scan_sc  fp16  16384   32    0.100    777.17     114688
# 16  seg_scan_sc  fp16  24576   32    0.100   1139.25     172032
# 17  seg_scan_sc  fp16  32768   32    0.100   1502.42     229376
# 18  seg_scan_sc  fp16  45056   32    0.100   2028.41     315392
# 19  seg_scan_sc  fp16   4096   64    0.100    247.70      28672
# 20  seg_scan_sc  fp16   8192   64    0.100    415.77      57344
# 21  seg_scan_sc  fp16  12288   64    0.100    565.25      86016
# 22  seg_scan_sc  fp16  16384   64    0.100    710.49     114688
# 23  seg_scan_sc  fp16  20480   64    0.100    861.96     143360
# 24  seg_scan_sc  fp16  24576   64    0.100   1023.91     172032
# 25  seg_scan_sc  fp16  28672   64    0.100   1194.42     200704
# 26  seg_scan_sc  fp16  32768   64    0.100   1315.81     229376
# 27  seg_scan_sc  fp16  36864   64    0.100   1484.67     258048
# 28  seg_scan_sc  fp16  40960   64    0.100   1637.36     286720
# 29  seg_scan_sc  fp16  45056   64    0.100   1812.34     315392
# 30  seg_scan_sc  fp16  49152   64    0.100   1967.70     344064
# 31  seg_scan_sc  fp16  16384  128    0.100    680.46     114688
# 32  seg_scan_sc  fp16  32768  128    0.100   1312.48     229376
# 33  seg_scan_sc  fp16  49152  128    0.100   1906.73     344064
# 0   seg_scan_sc  fp16   1024   32    0.400    242.21       7168
# 1   seg_scan_sc  fp16   2048   32    0.400    391.58      14336
# 2   seg_scan_sc  fp16   3072   32    0.400    540.41      21504
# 3   seg_scan_sc  fp16   4096   32    0.400    682.12      28672
# 4   seg_scan_sc  fp16   5120   32    0.400    825.24      35840
# 5   seg_scan_sc  fp16   6144   32    0.400    958.74      43008
# 6   seg_scan_sc  fp16   7168   32    0.400   1149.89      50176
# 7   seg_scan_sc  fp16   8192   32    0.400   1272.42      57344
# 8   seg_scan_sc  fp16   9216   32    0.400   1432.93      64512
# 9   seg_scan_sc  fp16  10240   32    0.400   1561.71      71680
# 10  seg_scan_sc  fp16  11264   32    0.400   1692.43      78848
# 11  seg_scan_sc  fp16  12288   32    0.400   1830.58      86016
# 12  seg_scan_sc  fp16  13312   32    0.400   2012.82      93184
# 13  seg_scan_sc  fp16  14336   32    0.400   2126.77     100352
# 14  seg_scan_sc  fp16  15360   32    0.400   2274.96     107520
# 15  seg_scan_sc  fp16  16384   32    0.400   2396.16     114688
# 16  seg_scan_sc  fp16  24576   32    0.400   3625.31     172032
# 17  seg_scan_sc  fp16  32768   32    0.400   4812.04     229376
# 18  seg_scan_sc  fp16  45056   32    0.400   6541.76     315392
# 19  seg_scan_sc  fp16   4096   64    0.400    663.06      28672
# 20  seg_scan_sc  fp16   8192   64    0.400   1224.90      57344
# 21  seg_scan_sc  fp16  12288   64    0.400   1795.62      86016
# 22  seg_scan_sc  fp16  16384   64    0.400   2420.66     114688
# 23  seg_scan_sc  fp16  20480   64    0.400   2959.66     143360
# 24  seg_scan_sc  fp16  24576   64    0.400   3521.31     172032
# 25  seg_scan_sc  fp16  28672   64    0.400   4147.09     200704
# 26  seg_scan_sc  fp16  32768   64    0.400   4695.20     229376
# 27  seg_scan_sc  fp16  36864   64    0.400   5213.41     258048
# 28  seg_scan_sc  fp16  40960   64    0.400   5816.84     286720
# 29  seg_scan_sc  fp16  45056   64    0.400   6322.15     315392
# 30  seg_scan_sc  fp16  49152   64    0.400   6962.96     344064
# 31  seg_scan_sc  fp16  16384  128    0.400   2405.85     114688
# 32  seg_scan_sc  fp16  32768  128    0.400   4755.85     229376
# 33  seg_scan_sc  fp16  49152  128    0.400   6956.05     344064
# 0   seg_scan_sc  fp16   1024   32    0.001    131.77       7168
# 1   seg_scan_sc  fp16   2048   32    0.001    133.12      14336
# 2   seg_scan_sc  fp16   3072   32    0.001    138.91      21504
# 3   seg_scan_sc  fp16   4096   32    0.001    137.09      28672
# 4   seg_scan_sc  fp16   5120   32    0.001    143.94      35840
# 5   seg_scan_sc  fp16   6144   32    0.001    152.61      43008
# 6   seg_scan_sc  fp16   7168   32    0.001    161.29      50176
# 7   seg_scan_sc  fp16   8192   32    0.001    169.40      57344
# 8   seg_scan_sc  fp16   9216   32    0.001    181.95      64512
# 9   seg_scan_sc  fp16  10240   32    0.001    191.17      71680
# 10  seg_scan_sc  fp16  11264   32    0.001    205.30      78848
# 11  seg_scan_sc  fp16  12288   32    0.001    215.93      86016
# 12  seg_scan_sc  fp16  13312   32    0.001    227.89      93184
# 13  seg_scan_sc  fp16  14336   32    0.001    239.00     100352
# 14  seg_scan_sc  fp16  15360   32    0.001    247.14     107520
# 15  seg_scan_sc  fp16  16384   32    0.001    259.65     114688
# 16  seg_scan_sc  fp16  24576   32    0.001    338.49     172032
# 17  seg_scan_sc  fp16  32768   32    0.001    416.97     229376
# 18  seg_scan_sc  fp16  45056   32    0.001    539.62     315392
# 19  seg_scan_sc  fp16   4096   64    0.001    129.65      28672
# 20  seg_scan_sc  fp16   8192   64    0.001    142.74      57344
# 21  seg_scan_sc  fp16  12288   64    0.001    159.96      86016
# 22  seg_scan_sc  fp16  16384   64    0.001    178.80     114688
# 23  seg_scan_sc  fp16  20480   64    0.001    201.59     143360
# 24  seg_scan_sc  fp16  24576   64    0.001    222.25     172032
# 25  seg_scan_sc  fp16  28672   64    0.001    242.12     200704
# 26  seg_scan_sc  fp16  32768   64    0.001    259.75     229376
# 27  seg_scan_sc  fp16  36864   64    0.001    283.37     258048
# 28  seg_scan_sc  fp16  40960   64    0.001    307.37     286720
# 29  seg_scan_sc  fp16  45056   64    0.001    331.96     315392
# 30  seg_scan_sc  fp16  49152   64    0.001    355.00     344064
# 31  seg_scan_sc  fp16  16384  128    0.001    146.84     114688
# 32  seg_scan_sc  fp16  32768  128    0.001    184.14     229376
# 33  seg_scan_sc  fp16  49152  128    0.001    229.48     344064
# 0   seg_scan_sc  fp16   1024   32    0.500    268.54       7168
# 1   seg_scan_sc  fp16   2048   32    0.500    457.38      14336
# 2   seg_scan_sc  fp16   3072   32    0.500    626.88      21504
# 3   seg_scan_sc  fp16   4096   32    0.500    806.53      28672
# 4   seg_scan_sc  fp16   5120   32    0.500   1003.38      35840
# 5   seg_scan_sc  fp16   6144   32    0.500   1165.59      43008
# 6   seg_scan_sc  fp16   7168   32    0.500   1339.75      50176
# 7   seg_scan_sc  fp16   8192   32    0.500   1544.37      57344
# 8   seg_scan_sc  fp16   9216   32    0.500   1728.12      64512
# 9   seg_scan_sc  fp16  10240   32    0.500   1910.98      71680
# 10  seg_scan_sc  fp16  11264   32    0.500   2051.71      78848
# 11  seg_scan_sc  fp16  12288   32    0.500   2251.37      86016
# 12  seg_scan_sc  fp16  13312   32    0.500   2403.23      93184
# 13  seg_scan_sc  fp16  14336   32    0.500   2612.21     100352
# 14  seg_scan_sc  fp16  15360   32    0.500   2767.02     107520
# 15  seg_scan_sc  fp16  16384   32    0.500   2988.43     114688
# 16  seg_scan_sc  fp16  24576   32    0.500   4405.12     172032
# 17  seg_scan_sc  fp16  32768   32    0.500   5856.91     229376
# 18  seg_scan_sc  fp16  45056   32    0.500   7991.03     315392
# 19  seg_scan_sc  fp16   4096   64    0.500    798.79      28672
# 20  seg_scan_sc  fp16   8192   64    0.500   1502.75      57344
# 21  seg_scan_sc  fp16  12288   64    0.500   2204.38      86016
# 22  seg_scan_sc  fp16  16384   64    0.500   2901.27     114688
# 23  seg_scan_sc  fp16  20480   64    0.500   3631.26     143360
# 24  seg_scan_sc  fp16  24576   64    0.500   4317.97     172032
# 25  seg_scan_sc  fp16  28672   64    0.500   5049.04     200704
# 26  seg_scan_sc  fp16  32768   64    0.500   5790.17     229376
# 27  seg_scan_sc  fp16  36864   64    0.500   6442.15     258048
# 28  seg_scan_sc  fp16  40960   64    0.500   7158.64     286720
# 29  seg_scan_sc  fp16  45056   64    0.500   7828.08     315392
# 30  seg_scan_sc  fp16  49152   64    0.500   8626.56     344064
# 31  seg_scan_sc  fp16  16384  128    0.500   2992.51     114688
# 32  seg_scan_sc  fp16  32768  128    0.500   5797.43     229376
# 33  seg_scan_sc  fp16  49152  128    0.500   8719.56     344064
# 0   seg_scan_sc  fp16   1024   32    0.010    124.38       7168
# 1   seg_scan_sc  fp16   2048   32    0.010    130.79      14336
# 2   seg_scan_sc  fp16   3072   32    0.010    137.62      21504
# 3   seg_scan_sc  fp16   4096   32    0.010    150.28      28672
# 4   seg_scan_sc  fp16   5120   32    0.010    163.34      35840
# 5   seg_scan_sc  fp16   6144   32    0.010    177.69      43008
# 6   seg_scan_sc  fp16   7168   32    0.010    189.71      50176
# 7   seg_scan_sc  fp16   8192   32    0.010    206.57      57344
# 8   seg_scan_sc  fp16   9216   32    0.010    220.62      64512
# 9   seg_scan_sc  fp16  10240   32    0.010    232.96      71680
# 10  seg_scan_sc  fp16  11264   32    0.010    242.83      78848
# 11  seg_scan_sc  fp16  12288   32    0.010    259.03      86016
# 12  seg_scan_sc  fp16  13312   32    0.010    273.87      93184
# 13  seg_scan_sc  fp16  14336   32    0.010    288.15     100352
# 14  seg_scan_sc  fp16  15360   32    0.010    303.72     107520
# 15  seg_scan_sc  fp16  16384   32    0.010    316.97     114688
# 16  seg_scan_sc  fp16  24576   32    0.010    421.33     172032
# 17  seg_scan_sc  fp16  32768   32    0.010    519.98     229376
# 18  seg_scan_sc  fp16  45056   32    0.010    684.68     315392
# 19  seg_scan_sc  fp16   4096   64    0.010    132.77      28672
# 20  seg_scan_sc  fp16   8192   64    0.010    161.43      57344
# 21  seg_scan_sc  fp16  12288   64    0.010    199.12      86016
# 22  seg_scan_sc  fp16  16384   64    0.010    228.36     114688
# 23  seg_scan_sc  fp16  20480   64    0.010    260.97     143360
# 24  seg_scan_sc  fp16  24576   64    0.010    293.36     172032
# 25  seg_scan_sc  fp16  28672   64    0.010    328.67     200704
# 26  seg_scan_sc  fp16  32768   64    0.010    358.26     229376
# 27  seg_scan_sc  fp16  36864   64    0.010    393.86     258048
# 28  seg_scan_sc  fp16  40960   64    0.010    418.24     286720
# 29  seg_scan_sc  fp16  45056   64    0.010    452.47     315392
# 30  seg_scan_sc  fp16  49152   64    0.010    505.59     344064
# 31  seg_scan_sc  fp16  16384  128    0.010    189.85     114688
# 32  seg_scan_sc  fp16  32768  128    0.010    276.99     229376
# 33  seg_scan_sc  fp16  49152  128    0.010    379.15     344064
# 0   seg_scan_sc  fp16   1024   32    0.200    172.46       7168
# 1   seg_scan_sc  fp16   2048   32    0.200    241.52      14336
# 2   seg_scan_sc  fp16   3072   32    0.200    331.42      21504
# 3   seg_scan_sc  fp16   4096   32    0.200    410.95      28672
# 4   seg_scan_sc  fp16   5120   32    0.200    466.48      35840
# 5   seg_scan_sc  fp16   6144   32    0.200    582.00      43008
# 6   seg_scan_sc  fp16   7168   32    0.200    646.62      50176
# 7   seg_scan_sc  fp16   8192   32    0.200    711.40      57344
# 8   seg_scan_sc  fp16   9216   32    0.200    800.08      64512
# 9   seg_scan_sc  fp16  10240   32    0.200    889.31      71680
# 10  seg_scan_sc  fp16  11264   32    0.200    932.25      78848
# 11  seg_scan_sc  fp16  12288   32    0.200    999.72      86016
# 12  seg_scan_sc  fp16  13312   32    0.200   1117.34      93184
# 13  seg_scan_sc  fp16  14336   32    0.200   1188.30     100352
# 14  seg_scan_sc  fp16  15360   32    0.200   1262.37     107520
# 15  seg_scan_sc  fp16  16384   32    0.200   1355.46     114688
# 16  seg_scan_sc  fp16  24576   32    0.200   1925.48     172032
# 17  seg_scan_sc  fp16  32768   32    0.200   2600.64     229376
# 18  seg_scan_sc  fp16  45056   32    0.200   3553.09     315392
# 19  seg_scan_sc  fp16   4096   64    0.200    392.69      28672
# 20  seg_scan_sc  fp16   8192   64    0.200    668.95      57344
# 21  seg_scan_sc  fp16  12288   64    0.200    997.42      86016
# 22  seg_scan_sc  fp16  16384   64    0.200   1263.59     114688
# 23  seg_scan_sc  fp16  20480   64    0.200   1600.49     143360
# 24  seg_scan_sc  fp16  24576   64    0.200   1827.84     172032
# 25  seg_scan_sc  fp16  28672   64    0.200   2133.14     200704
# 26  seg_scan_sc  fp16  32768   64    0.200   2441.48     229376
# 27  seg_scan_sc  fp16  36864   64    0.200   2716.57     258048
# 28  seg_scan_sc  fp16  40960   64    0.200   3068.29     286720
# 29  seg_scan_sc  fp16  45056   64    0.200   3346.42     315392
# 30  seg_scan_sc  fp16  49152   64    0.200   3626.62     344064
# 31  seg_scan_sc  fp16  16384  128    0.200   1274.13     114688
# 32  seg_scan_sc  fp16  32768  128    0.200   2405.96     229376
# 33  seg_scan_sc  fp16  49152  128    0.200   3589.85     344064
# 0   seg_scan_sc  fp16   1024   32    0.600    303.77       7168
# 1   seg_scan_sc  fp16   2048   32    0.600    526.77      14336
# 2   seg_scan_sc  fp16   3072   32    0.600    730.72      21504
# 3   seg_scan_sc  fp16   4096   32    0.600    948.04      28672
# 4   seg_scan_sc  fp16   5120   32    0.600   1149.91      35840
# 5   seg_scan_sc  fp16   6144   32    0.600   1378.97      43008
# 6   seg_scan_sc  fp16   7168   32    0.600   1600.37      50176
# 7   seg_scan_sc  fp16   8192   32    0.600   1804.35      57344
# 8   seg_scan_sc  fp16   9216   32    0.600   2042.74      64512
# 9   seg_scan_sc  fp16  10240   32    0.600   2229.57      71680
# 10  seg_scan_sc  fp16  11264   32    0.600   2485.08      78848
# 11  seg_scan_sc  fp16  12288   32    0.600   2660.45      86016
# 12  seg_scan_sc  fp16  13312   32    0.600   2913.05      93184
# 13  seg_scan_sc  fp16  14336   32    0.600   3116.14     100352
# 14  seg_scan_sc  fp16  15360   32    0.600   3353.33     107520
# 15  seg_scan_sc  fp16  16384   32    0.600   3541.71     114688
# 16  seg_scan_sc  fp16  24576   32    0.600   5301.58     172032
# 17  seg_scan_sc  fp16  32768   32    0.600   7012.95     229376
# 18  seg_scan_sc  fp16  45056   32    0.600   9493.15     315392
# 19  seg_scan_sc  fp16   4096   64    0.600    922.97      28672
# 20  seg_scan_sc  fp16   8192   64    0.600   1781.22      57344
# 21  seg_scan_sc  fp16  12288   64    0.600   2641.33      86016
# 22  seg_scan_sc  fp16  16384   64    0.600   3524.24     114688
# 23  seg_scan_sc  fp16  20480   64    0.600   4390.67     143360
# 24  seg_scan_sc  fp16  24576   64    0.600   5185.37     172032
# 25  seg_scan_sc  fp16  28672   64    0.600   6018.73     200704
# 26  seg_scan_sc  fp16  32768   64    0.600   6826.51     229376
# 27  seg_scan_sc  fp16  36864   64    0.600   7726.49     258048
# 28  seg_scan_sc  fp16  40960   64    0.600   8520.17     286720
# 29  seg_scan_sc  fp16  45056   64    0.600   9404.52     315392
# 30  seg_scan_sc  fp16  49152   64    0.600  10284.39     344064
# 31  seg_scan_sc  fp16  16384  128    0.600   3534.81     114688
# 32  seg_scan_sc  fp16  32768  128    0.600   6954.03     229376
# 33  seg_scan_sc  fp16  49152  128    0.600  10356.76     344064

# %%
filtered_32 = tot_dataframe[tot_dataframe["s"]==32]

plt.figure(figsize=(8, 5))
sns.lineplot(x='size', y='bandwidth_mbps', hue='density', data=filtered_32, marker='o')

plt.xlabel('Data Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('Bandwidth vs Data Size for Different Densities for S=32')
plt.tight_layout()

plt.grid(True)
plt.show()

# %%
filtered_32 = tot_dataframe[tot_dataframe["s"]==64]

plt.figure(figsize=(8, 5))
sns.lineplot(x='size', y='bandwidth_mbps', hue='density', data=filtered_32, marker='o')

plt.xlabel('Data Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('Bandwidth vs Data Size for Different Densities for S=64')
plt.tight_layout()

plt.grid(True)
plt.show()

# %%
filtered_32 = tot_dataframe[tot_dataframe["s"]==128]

plt.figure(figsize=(8, 5))
sns.lineplot(x='size', y='bandwidth_mbps', hue='density', data=filtered_32, marker='o')

plt.xlabel('Data Size')
plt.ylabel('Bandwidth (MB/s)')
plt.title('Bandwidth vs Data Size for Different Densities for S=128')
plt.tight_layout()

plt.grid(True)
plt.show()
